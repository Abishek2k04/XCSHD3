# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mlxtend.frequent_patterns import apriori,association_rules

# %%
ds=pd.read_csv('retail_dataset.csv')

# %%
items=(ds['0'].unique())

# %%
itemset=set(items)
encoded_values=[]

for index, row in ds.iterrows():
    rowset=set(row)
    labels={}

    uncommons=list(itemset-rowset)
    commons=list(itemset.intersection(rowset))

    for uc in uncommons:
        labels[uc]=0
    for com in commons:
        labels[com]=1
    encoded_values.append(labels)
encoded_values[0]
# Out:
# {'Milk': 0,
#  'Bagel': 0,
#  'Eggs': 1,
#  'Cheese': 1,
#  'Wine': 1,
#  'Bread': 1,
#  'Diaper': 1,
#  'Meat': 1,
#  'Pencil': 1}

# %%
b_data=pd.DataFrame(encoded_values)

# %%
import warnings
warnings.simplefilter('ignore')

# %%
freq_items=apriori(b_data,min_support=0.2,use_colnames=True,verbose=1)
# Out:
# Processing 174 combinations | Sampling itemset size 3

# %%
rules=association_rules(freq_items,metric='confidence',min_threshold=0.6)

# %%
rules
# Out:
#        antecedents consequents  antecedent support  consequent support  \
# 0         (Cheese)      (Milk)            0.501587            0.501587
# 1           (Milk)    (Cheese)            0.501587            0.501587
# 2          (Bagel)     (Bread)            0.425397            0.504762
# 3           (Eggs)    (Cheese)            0.438095            0.501587
# 4           (Eggs)      (Meat)            0.438095            0.476190
# 5           (Wine)    (Cheese)            0.438095            0.501587
# 6         (Cheese)      (Meat)            0.501587            0.476190
# 7           (Meat)    (Cheese)            0.476190            0.501587
# 8   (Cheese, Meat)      (Milk)            0.323810            0.501587
# 9   (Cheese, Milk)      (Meat)            0.304762            0.476190
# 10    (Meat, Milk)    (Cheese)            0.244444            0.501587
# 11    (Eggs, Meat)    (Cheese)            0.266667            0.501587
# 12  (Eggs, Cheese)      (Meat)            0.298413            0.476190
# 13  (Meat, Cheese)      (Eggs)            0.323810            0.438095
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 0   0.304762    0.607595  1.211344  0.053172    1.270148       0.350053
# 1   0.304762    0.607595  1.211344  0.053172    1.270148       0.350053
# 2   0.279365    0.656716  1.301042  0.064641    1.442650       0.402687
# 3   0.298413    0.681159  1.358008  0.078670    1.563203       0.469167
# 4   0.266667    0.608696  1.278261  0.058050    1.338624       0.387409
# 5   0.269841    0.615942  1.227986  0.050098    1.297754       0.330409
# 6   0.323810    0.645570  1.355696  0.084958    1.477891       0.526414
# 7   0.323810    0.680000  1.355696  0.084958    1.557540       0.500891
# 8   0.203175    0.627451  1.250931  0.040756    1.337845       0.296655
# 9   0.203175    0.666667  1.400000  0.058050    1.571429       0.410959
# 10  0.203175    0.831169  1.657077  0.080564    2.952137       0.524816
# 11  0.215873    0.809524  1.613924  0.082116    2.616667       0.518717
# 12  0.215873    0.723404  1.519149  0.073772    1.893773       0.487091
# 13  0.215873    0.666667  1.521739  0.074014    1.685714       0.507042

# %%
for _ in range(14):
    print('Rules',rules.antecedants,'--->',rules.consequesnt[i])
    print('Support',rules.suppoer[i])
    print("confidence:",rules.confidence[i])
    print('********************************************************')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3600\3677476277.py in ?()
#       1 for _ in range(14):
# ----> 2     print('Rules',rules.antecedants,'--->',rules.consequesnt[i])
#       3     print('Support',rules.suppoer[i])
#       4     print("confidence:",rules.confidence[i])
#       5     print('********************************************************')
#
# ~\anaconda3\envs\Abishek\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'antecedants'
