# %% [markdown]
# # 1

# %% [markdown]
# A3 Import System Lib

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# A2 Import DataHandling Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# A3 DataViz Lib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# pip install scikit-image

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
veera =os.listdir("imgrecz/veeramani")

# %%
arsha=os.listdir("imgrecz/arshath")

# %%
abi=os.listdir("imgrecz/abishek")

# %%
limit=10
veera_images=[None]*limit
j=0
for i in veera:
    if (j<limit):
         veera_images[j]=imread("imgrecz/veeramani/"+i)
         j+=1
    else:
        break

# %%
arsha_images=[None]*limit
j=0
for i in arsha:
    if (j<limit):
         arsha_images[j]=imread("imgrecz/arshath/"+i)
         j+=1
    else:
        break

# %%
abi_images=[None]*limit
j=0
for i in abi:
    if (j<limit):
         abi_images[j]=imread("imgrecz/abishek/"+i)
         j+=1
    else:
        break

# %%
view = imshow(veera_images[0])
plt.show()

# %%
view3=imshow(arsha_images[2])
plt.show()

# %%
view2=imshow(abi_images[2])
plt.show()

# %%
veera_gray =[None]*limit
j = 0
for i in veera:
    if j < limit: 
        veera_gray[j]=rgb2gray(veera_images[j])
        j+=1
    else:
        break

# %%
arsha_gray = [None] * limit
j = 0
for i in arsha:
    if j < limit: 
        arsha_gray[j]=rgb2gray(arsha_images[j])
        j+=1
    else:
        break

# %%
abi_gray = [None] * limit
j = 0
for i in abi:
    if j < limit: 
        abi_gray[j]=rgb2gray(abi_images[j])
        j+=1
    else:
        break

# %%
veera_gray[1]
# Out:
# array([[0.3537349 , 0.35765647, 0.36157804, ..., 0.59709882, 0.59766431,
#         0.59739647],
#        [0.3537349 , 0.35765647, 0.36157804, ..., 0.59709882, 0.59766431,
#         0.59739647],
#        [0.3537349 , 0.35765647, 0.36157804, ..., 0.59709882, 0.59766431,
#         0.59739647],
#        ...,
#        [0.21557686, 0.21557686, 0.20716039, ..., 0.19969804, 0.21146275,
#         0.21930588],
#        [0.21949843, 0.21557686, 0.21222078, ..., 0.20361961, 0.21538431,
#         0.21930588],
#        [0.21949843, 0.21557686, 0.21222078, ..., 0.20361961, 0.21538431,
#         0.22322745]])

# %%
view=imshow(veera_gray[1])
plt.show()

# %%
view=imshow(arsha_gray[1])
plt.show()

# %%
view=imshow(abi_gray[1])
plt.show()

# %%
for j in range(10):
    vr=veera_gray[j]
    veera_gray[j]=resize(vr,(512,512))

# %%
for j in range(10):
    ma=arsha_gray[j]
    arsha_gray[j]=resize(ma,(512,512))

# %%
for j in range(10):
    abi=abi_gray[j]
    abi_gray[j]=resize(abi,(512,512))

# %% [markdown]
# ## find Out Number Of Gray_Scale Imaages

# %%
len_of_images_veera=len(veera_gray)
len_of_images_veera
# Out:
# 10

# %%
len_of_images_arsha=len(arsha_gray)
len_of_images_arsha
# Out:
# 10

# %%
len_of_images_abi=len(abi_gray)
len_of_images_abi
# Out:
# 10

# %% [markdown]
# ## Create Variable IMG_SIZE_VIJAY

# %%
image_size_veera=veera_gray[1].shape
image_size_veera
# Out:
# (512, 512)

# %%
image_size_arsha=arsha_gray[1].shape
image_size_arsha
# Out:
# (512, 512)

# %%
image_size_abi=abi_gray[1].shape
image_size_abi
# Out:
# (512, 512)

# %% [markdown]
# ## Flatten_Size_vijay

# %%
flatten_size_veera=image_size_veera[0]*image_size_veera[1]

# %%
flatten_size_arsha=image_size_arsha[0]*image_size_arsha[1]

# %%
flatten_size_abi=image_size_abi[0]*image_size_abi[1]

# %%
flatten_size_veera
# Out:
# 262144

# %%
flatten_size_arsha
# Out:
# 262144

# %%
flatten_size_abi
# Out:
# 262144

# %% [markdown]
# ## Now Flatten Image from (512,512) matrix to 262144,1 vector

# %%
for i in range(len_of_images_veera):
    veera_gray[i]=np.ndarray.flatten(veera_gray[i]).reshape(flatten_size_veera,1)

# %%
for i in range(len_of_images_arsha):
    arsha_gray[i]=np.ndarray.flatten(arsha_gray[i]).reshape(flatten_size_arsha,1)

# %%
for i in range(len_of_images_abi):
    abi_gray[i]=np.ndarray.flatten(abi_gray[i]).reshape(flatten_size_abi,1)

# %% [markdown]
# ## Stack The individual Image Element into one array

# %%
veera_gray=np.dstack(veera_gray)

# %%
veera_gray
# Out:
# array([[[0.54582667, 0.35540405, 0.84106578, ..., 0.43701327,
#          0.40974508, 0.80805307]],
#
#        [[0.54578074, 0.3614707 , 0.84823321, ..., 0.42786727,
#          0.40608035, 0.73835332]],
#
#        [[0.54396016, 0.36157803, 0.85971476, ..., 0.41615008,
#          0.40098242, 0.68647419]],
#
#        ...,
#
#        [[0.23350286, 0.20027547, 0.21459686, ..., 0.16817181,
#          0.24114796, 0.18013633]],
#
#        [[0.19889734, 0.20283081, 0.21339453, ..., 0.16874565,
#          0.23589765, 0.17666208]],
#
#        [[0.18336074, 0.21800871, 0.2235559 , ..., 0.16108147,
#          0.24112225, 0.17234407]]])

# %%
veera_gray.shape
# Out:
# (262144, 1, 10)

# %%
arsha_gray=np.dstack(arsha_gray)

# %%
arsha_gray
# Out:
# array([[[0.97225137, 0.87405765, 0.93782199, ..., 0.6498375 ,
#          0.84408132, 0.99076342]],
#
#        [[0.97225137, 0.87439063, 0.94310275, ..., 0.66008458,
#          0.84042807, 0.99534265]],
#
#        [[0.97225137, 0.8746231 , 0.94212253, ..., 0.7195231 ,
#          0.8380219 , 0.99551314]],
#
#        ...,
#
#        [[0.6750387 , 0.16434617, 0.46086398, ..., 0.69354324,
#          0.29457508, 0.79654771]],
#
#        [[0.65606343, 0.17009537, 0.44811519, ..., 0.62645321,
#          0.29786875, 0.76445465]],
#
#        [[0.62844439, 0.16399051, 0.4396354 , ..., 0.38467858,
#          0.3129216 , 0.78386522]]])

# %%
arsha_gray.shape
# Out:
# (262144, 1, 10)

# %%
abi_gray=np.dstack(abi_gray)

# %%
abi_gray
# Out:
# array([[[0.98838837, 0.86933882, 0.0343102 , ..., 0.1812    ,
#          0.4294593 , 0.27645462]],
#
#        [[0.98845059, 0.86933882, 0.0343102 , ..., 0.1812    ,
#          0.43711598, 0.27645462]],
#
#        [[0.9880835 , 0.86933882, 0.0343102 , ..., 0.1812    ,
#          0.44467895, 0.27470025]],
#
#        ...,
#
#        [[0.7374164 , 0.52979512, 0.886359  , ..., 0.88684078,
#          0.40169956, 0.84241494]],
#
#        [[0.7508847 , 0.52952062, 0.88896316, ..., 0.88648666,
#          0.40131866, 0.8399019 ]],
#
#        [[0.74860194, 0.52628291, 0.89024993, ..., 0.89035681,
#          0.40080871, 0.83611313]]])

# %%
abi_gray.shape
# Out:
# (262144, 1, 10)

# %%
veera_gray = np.rollaxis(veera_gray,axis=2,start=0)

# %%
arsha_gray =np.rollaxis(arsha_gray,axis=2,start=0)

# %%
abi_gray=np.rollaxis(abi_gray,axis=2,start=0)

# %%
abi_gray.shape
# Out:
# (10, 262144, 1)

# %%
arsha_gray.shape
# Out:
# (10, 262144, 1)

# %%
veera_gray.shape
# Out:
# (10, 262144, 1)

# %%
veera_gray=veera_gray.reshape(len_of_images_veera,flatten_size_veera)

# %%
veera_gray.shape
# Out:
# (10, 262144)

# %%
arsha_gray=arsha_gray.reshape(len_of_images_arsha,flatten_size_arsha)

# %%
arsha_gray.shape
# Out:
# (10, 262144)

# %%
abi_gray=abi_gray.reshape(len_of_images_abi,flatten_size_abi)
abi_gray.shape
# Out:
# (10, 262144)

# %%
veera_data=pd.DataFrame(veera_gray)

# %%
veera_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.545827  0.545781  0.543960  0.543877  0.546278  0.543230  0.544933
# 1  0.355404  0.361471  0.361578  0.364362  0.368420  0.367449  0.367451
# 2  0.841066  0.848233  0.859715  0.873537  0.886928  0.895930  0.903343
# 3  0.881025  0.882491  0.886155  0.887853  0.886050  0.886311  0.879669
# 4  0.720249  0.679173  0.650707  0.628196  0.611227  0.603787  0.600842
# 5  0.712080  0.724290  0.731342  0.735203  0.743098  0.752774  0.756991
# 6  0.420326  0.418928  0.418505  0.419187  0.419187  0.418504  0.417847
# 7  0.437013  0.427867  0.416150  0.409729  0.409683  0.407484  0.407402
# 8  0.409745  0.406080  0.400982  0.396861  0.409841  0.425614  0.443445
# 9  0.808053  0.738353  0.686474  0.653597  0.642590  0.636006  0.634363
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.551068  0.555974  0.559588  ...  0.179063  0.174889  0.176483  0.173288
# ...

# %%
arsha_data=pd.DataFrame(arsha_gray)

# %%
arsha_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.972251  0.972251  0.972251  0.972251  0.972251  0.972251  0.972251
# 1  0.874058  0.874391  0.874623  0.873567  0.876455  0.877926  0.884996
# 2  0.937822  0.943103  0.942123  0.946859  0.952170  0.953093  0.959902
# 3  0.942263  0.942263  0.942263  0.942263  0.942263  0.942263  0.942266
# 4  0.442616  0.423200  0.410695  0.404127  0.394751  0.391637  0.383360
# 5  0.487192  0.480567  0.468445  0.469325  0.461320  0.444079  0.425616
# 6  0.810037  0.810056  0.810612  0.812287  0.806922  0.805900  0.806156
# 7  0.649838  0.660085  0.719523  0.703139  0.701264  0.705488  0.710735
# 8  0.844081  0.840428  0.838022  0.834455  0.831606  0.834664  0.834192
# 9  0.990763  0.995343  0.995513  0.998844  0.996953  0.997137  0.998366
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.972251  0.972251  0.972251  ...  0.618551  0.612646  0.608056  0.622175
# ...

# %%
abi_data=pd.DataFrame(abi_gray)

# %%
abi_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.988388  0.988451  0.988083  0.987750  0.987520  0.987259  0.986632
# 1  0.869339  0.869339  0.869339  0.869339  0.869339  0.868033  0.867419
# 9   0.808053  0.738353  0.686474  0.653597  0.642590  0.636006  0.634363
# 10  0.437013  0.427867  0.416150  0.409729  0.409683  0.407484  0.407402
# 11  0.874058  0.874391  0.874623  0.873567  0.876455  0.877926  0.884996
# ...

# %% [markdown]
# kollywood_a1.to_csv("machans.csv")

# %%
x=kollywood_a1.values[:,:-1]

# %%
y=kollywood_a1.values[:,-1]

# %% [markdown]
# ### TRAINING SET TEDTING SET

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (24, 262144)

# %%
x_test.shape
# Out:
# (6, 262144)

# %%
y_train.shape
# Out:
# (24,)

# %%
y_test.shape
# Out:
# (6,)

# %%
#PCA

# %%
from sklearn import decomposition

# %%
pca=decomposition.PCA(n_components=20,whiten=True,random_state=1)

# %%
pca
# Out:
# PCA(n_components=20, random_state=1, whiten=True)

# %%
pca.fit(x_train)
# Out:
# PCA(n_components=20, random_state=1, whiten=True)

# %%
x_train_pca=pca.transform(x_train)
x_test_pca=pca.transform(x_test)

# %% [markdown]
# x_train_pca

# %% [markdown]
# x_test_pca

# %% [markdown]
# x_test_pca.shape

# %% [markdown]
# x_train_pca.shape

# %% [markdown]
# ### Reshae Image by Original Matrix size (Eigen)

# %%
eigen=(np.reshape(x[10],(512,512)).astype(np.float64))

# %%
eigen
# Out:
# array([[0.43701327, 0.42786727, 0.41615008, ..., 0.46835053, 0.46635201,
#         0.45744832],
#        [0.42437516, 0.41639856, 0.4093569 , ..., 0.46882365, 0.46622298,
#         0.45758627],
#        [0.4156537 , 0.4086976 , 0.40776048, ..., 0.46948364, 0.46604127,
#         0.45541273],
#        ...,
#        [0.17008299, 0.18216219, 0.19724297, ..., 0.16872585, 0.16544967,
#         0.16107066],
#        [0.16705427, 0.17992799, 0.1842682 , ..., 0.16814564, 0.16841311,
#         0.16108034],
#        [0.15959896, 0.17743356, 0.17716025, ..., 0.16817181, 0.16874565,
#         0.16108147]])

# %%
fig =plt.figure(figsize=(30,30))
for i in range(10):
    ex=fig.add_subplot(3, 10, i+1, xticks=[], yticks=[])
    ex.imshow(pca.components_[i].reshape(eigen.shape),cmap=plt.cm.bone)   
plt.show()

# %%
from sklearn import svm

# %%
clf = svm.SVC(C=2, gamma=0.006, kernel='rbf')
clf.fit(x_train_pca, y_train)
# Out:
# SVC(C=2, gamma=0.006)

# %%
y_pred = clf.predict(x_test_pca)

# %%
y_pred
# Out:
# array(['dhanush', 'veeramani', 'arshath', 'veeramani', 'arshath',
#        'dhanush'], dtype=object)

# %%
for i in (np.random.randint(0,6,6)):
    predicted_images = (np.reshape(x_test[i], (512,512)).astype(np.float64))
    plt.title('predicted label: {0}'. format(y_pred[i]))
    plt.imshow(predicted_images, interpolation='nearest', cmap='gray')
    plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
 print(classification_report(y_test,y_pred))
accuracy
# Out:
#               precision    recall  f1-score   support
#
#      arshath       1.00      1.00      1.00         2
#      dhanush       1.00      1.00      1.00         2
#    veeramani       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
# 1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[2, 0, 0],
#        [0, 2, 0],
#        [0, 0, 2]])
